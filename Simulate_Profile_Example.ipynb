# %%
from simulate_profile_fit import simulate_profile_fit

#--------set constants here----------#
ACCUMULATION_RATE   = 0.5       #cm/y, the vertical sediment accumulation rate
CORE_DEPTH          = 200       #cm, the total core recovery length
DECAY_CONST         = -0.0311   #y**-1, the radioactive decay constant
ACTIVITY_INITIAL    = 50        #dpm/g, the activity at t=0
SUPPORTED_LEVEL     = 4         #dpm/g, the supported or "background" activity level
NOISE_AMPLITUDE     = 0.6       #dpm/g, the amount of random noise added or subtracted to each point
NUM_POINTS_MODELED  = 100       #points, the number of samples in this curve
SUPLVL_DEPTH_GUESS  = 50        #cm, your guess for the depth at which you reach supported levels
#------------------------------------#

simulate_profile_fit(ACCUMULATION_RATE,
                     CORE_DEPTH,
                     DECAY_CONST,
                     ACTIVITY_INITIAL,
                     SUPPORTED_LEVEL,
                     NOISE_AMPLITUDE,
                     NUM_POINTS_MODELED,
                     SUPLVL_DEPTH_GUESS,
                     #SUPLVL_VALUE = 5 #<---OPTIONAL PARAMETER TO FORCE A CUSTOM SUPPORTED LEVEL
                    )
